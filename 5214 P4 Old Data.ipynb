# %%
import pandas as pd 
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
data = '/Users/William/Desktop/Jupyter/P4Data.csv'
data = pd.read_csv(data)

# %%
data.head()
# Out:
#    Unnamed: 0 Country  Year Country Code   Debt  Account Balance  Corruption  \
# 0          37  Uganda  1997          UGA  79.12        -5.036102          26
# 1          38  Uganda  1998          UGA  75.51        -5.523161          26
# 2          39  Uganda  1999          UGA  76.02        -4.887837          26
# 3          40  Uganda  2000          UGA  77.58        -5.793407          26
# 4          41  Uganda  2001          UGA  81.47        -5.232146          26
#
#    Foreign_Investment       GDP  Inflation  ...  Delta_Account_Balance  \
# 0            2.791365  2.078453   8.169021  ...              -1.537102
# 1            3.189155  1.915019   0.068804  ...              -0.487060
# 2            2.337226  4.939167   5.777369  ...               0.635324
# 3            2.594762  0.098864   3.392022  ...              -0.905570
# 4            2.593888  1.997414   1.865125  ...               0.561261
#
#    Delta_Corruption  Delta_Investment  Delta_GDP  Delta_Inflation  \
# ...

# %%
#X = data[['Debt', 'Account Balance', 'Corruption', 'Foreign_Investment', 'GDP', 'Inflation',]]
X = data.drop(['New Conflict', 'Country', 'Country Code', 'Country-Year', 'Delta_Corruption', 'Delta_Ethnicity', 'Delta_Religion'], axis = 1)
y = data['New Conflict']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
clf = RandomForestClassifier(n_estimators = 100)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.912621359223301
